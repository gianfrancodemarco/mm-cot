# %%
import pandas as pd
from src import constants

dataframe = pd.read_csv(constants.FAKEDDIT_DATASET_PATH)[:2000]

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from urllib import request
from src.data.fakeddit.labels import convert_int_to_label

random_number = np.random.randint(0, 2000)
el = dataframe.iloc[random_number]
image = np.array(Image.open(request.urlopen(el["image_url"])))

fig, ax = plt.subplots()
ax.imshow(image)
ax.set_title(f"{random_number}: {el['title']}\n{el['title']}")
plt.show()
